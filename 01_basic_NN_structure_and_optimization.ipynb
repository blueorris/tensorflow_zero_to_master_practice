# %% [markdown]
# ## Common ways to improve a deep model:
# * Adding layers
# * Increase the number of hidden units
# * Change the activation functions
# * Change the optimization function
# * Change the learning rate (most effective)
# * Fitting on more data
# * Fittiing for longer

# %%
import tensorflow as tf 
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create features (using tensors)
X = tf.constant([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

# Create labels (using tensors)
y = tf.constant([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

# Visualize it
plt.scatter(X, y);
# Out:
# 2021-12-14 12:43:31.075767: I tensorflow/core/platform/cpu_feature_guard.cc:145] This TensorFlow binary is optimized with Intel(R) MKL-DNN to use the following CPU instructions in performance critical operations:  SSE4.1 SSE4.2
# To enable them in non-MKL-DNN operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-12-14 12:43:31.076704: I tensorflow/core/common_runtime/process_util.cc:115] Creating new thread pool with default inter op setting: 8. Tune using inter_op_parallelism_threads for best performance.

# %%
# Create a model using the Sequential API
model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

# Compile the model
model_1.compile(loss=tf.keras.losses.mae,
             optimizer=tf.keras.optimizers.SGD(),
             metrics=["mae"])

# Fit the model
model_1.fit(X, y, epochs=10)
# Out:
# Train on 8 samples
# Epoch 1/10
# 8/8 [==============================] - 0s 40ms/sample - loss: 7.8360 - mae: 7.8360
# Epoch 2/10
# 8/8 [==============================] - 0s 194us/sample - loss: 7.7035 - mae: 7.7035
# Epoch 3/10
# 8/8 [==============================] - 0s 168us/sample - loss: 7.5710 - mae: 7.5710
# Epoch 4/10
# 8/8 [==============================] - 0s 134us/sample - loss: 7.4775 - mae: 7.4775
# Epoch 5/10
# 8/8 [==============================] - 0s 275us/sample - loss: 7.4719 - mae: 7.4719
# Epoch 6/10
# 8/8 [==============================] - 0s 298us/sample - loss: 7.4663 - mae: 7.4663
# Epoch 7/10
# 8/8 [==============================] - 0s 219us/sample - loss: 7.4606 - mae: 7.4606
# Epoch 8/10
# 8/8 [==============================] - 0s 203us/sample - loss: 7.4550 - mae: 7.4550
# Epoch 9/10
# 8/8 [==============================] - 0s 192us/sample - loss: 7.4494 - mae: 7.4494
# Epoch 10/10
# ...

# %%
test_y = model_1.predict(X)

plt.scatter(X, test_y, color='red')
plt.show()

# %%
# Create a model using the Sequential API
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(100, activation="relu"),
    tf.keras.layers.Dense(1),
])

# Compile the model
model_2.compile(loss=tf.keras.losses.mae,
               optimizers=tf.keras.optimizers.Adam(lr=0.0001),
               metrics=["mae"])

# Fit the model
model_2.fit(X, y, epochs=100)
# Out:
# Train on 8 samples
# Epoch 1/100
# 8/8 [==============================] - 1s 72ms/sample - loss: 13.8014 - mae: 13.8014
# Epoch 2/100
# 8/8 [==============================] - 0s 423us/sample - loss: 12.6063 - mae: 12.6063
# Epoch 3/100
# 8/8 [==============================] - 0s 641us/sample - loss: 11.8466 - mae: 11.8466
# Epoch 4/100
# 8/8 [==============================] - 0s 585us/sample - loss: 11.0935 - mae: 11.0935
# Epoch 5/100
# 8/8 [==============================] - 0s 536us/sample - loss: 10.3612 - mae: 10.3612
# Epoch 6/100
# 8/8 [==============================] - 0s 687us/sample - loss: 9.7969 - mae: 9.7969
# Epoch 7/100
# 8/8 [==============================] - 0s 592us/sample - loss: 9.2413 - mae: 9.2413
# Epoch 8/100
# 8/8 [==============================] - 0s 636us/sample - loss: 8.6467 - mae: 8.6467
# Epoch 9/100
# 8/8 [==============================] - 0s 499us/sample - loss: 8.0189 - mae: 8.0189
# Epoch 10/100
# ...

# %%
model_2.predict([17])
# Out:
# array([[30.50601]], dtype=float32)

# %%
# Create a model using the Sequential API
model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(1),
])

# Compile the model
model_3.compile(loss=tf.keras.losses.mae,
               optimizers=tf.keras.optimizers.Adam(lr=0.0001),
               metrics=["mae"])

# Fit the model
model_3.fit(X, y, epochs=100)
# Out:
# Train on 8 samples
# Epoch 1/100
# 8/8 [==============================] - 0s 42ms/sample - loss: 13.8873 - mae: 13.8873
# Epoch 2/100
# 8/8 [==============================] - 0s 227us/sample - loss: 13.5659 - mae: 13.5659
# Epoch 3/100
# 8/8 [==============================] - 0s 194us/sample - loss: 13.3322 - mae: 13.3322
# Epoch 4/100
# 8/8 [==============================] - 0s 176us/sample - loss: 13.1361 - mae: 13.1361
# Epoch 5/100
# 8/8 [==============================] - 0s 165us/sample - loss: 12.9614 - mae: 12.9614
# Epoch 6/100
# 8/8 [==============================] - 0s 174us/sample - loss: 12.8010 - mae: 12.8010
# Epoch 7/100
# 8/8 [==============================] - 0s 161us/sample - loss: 12.6505 - mae: 12.6505
# Epoch 8/100
# 8/8 [==============================] - 0s 267us/sample - loss: 12.5076 - mae: 12.5076
# Epoch 9/100
# 8/8 [==============================] - 0s 284us/sample - loss: 12.3704 - mae: 12.3704
# Epoch 10/100
# ...

# %%
model_3.predict([17])
# Out:
# array([[30.080072]], dtype=float32)

# %%
test_y = model_3.predict(X)
plt.scatter(X, test_y, color='red')
plt.show()
